# %% [markdown]
# XGBoost workspace

# %% [markdown]
# Upload data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fecd4102-0540-4931-a0a8-0444777aab12" name="files[]" multiple disabled />
#      <output id="result-fecd4102-0540-4931-a0a8-0444777aab12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EURUSD15m1y41c.csv to EURUSD15m1y41c (1).csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
#      73     if result['action'] != 'append':
#      74       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# Read data

# %%
import io
import pandas as pd
import numpy as np
df = pd.read_csv(io.BytesIO(uploaded['EURUSD15m1y41c.csv']))
df = df.drop(columns=['Date'])

# %% [markdown]
# Split data, dmatrix

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
#df = df.to_numpy()
X = df[:,0:40]
Y = df[:,41]
data_dmatrix = xgb.DMatrix(data=X,label=Y)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (21562, 40) (21562,)
# (5391, 40) (5391,)

# %% [markdown]
# Initiate XGBoost regressor

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %% [markdown]
# Fit regressor on training set and make predictions on test set

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)
# Out:
# [10:46:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %% [markdown]
# Calculate loss (RMSE)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
